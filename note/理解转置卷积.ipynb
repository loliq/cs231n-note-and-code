# %% [markdown]
# 1. 正常卷积，no padding, no stride

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 卷积的另外一种图示，计算机计算的形式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 转置卷积

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
