# %% [markdown]
# ### 可视化深度学习

# %% [markdown]
# #### 1. 选择网络中的一层，丢进去很多的图片，看哪一张能激活这一层，但是这样在视觉上不直观

# %% [markdown]
# #### 2. 查看卷积层的权重，例如convNet的第一层
#
#     - 这种方法只对第一层卷积层有较强的解释性
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. 尝试去理解NN的最后一层发生了什么
#  - 这个时候可以用k近邻法聚类，利用的是NN的最后一层，如AlexNet的4096维的特征向量空间进行k近邻。
#
#   此处不用像素空间作为k近邻的原因是：像素空间在它的近邻和特征空间之间是非常不同的。但是这些图片的语义内容在特征空间是很近的。

# %% [markdown]
# ### 2. t-SNE 可视化工具，可视化非线性降维工具，类似PCA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **如上图，将图像从4096维降到2维进行可视化，这样可以看到有自然集群**
# 方法：
# 1. 采集很多图像

# %% [markdown]
# ### 3. 可以使用遮挡住图片的一部分，然后再进行预测，绘制heatmap。判断被遮挡的那部分对分类结果的贡献
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Saliency Maps显著图：Segment without supervision
#
# 计算相对图像输入像素的预测类别分值。告诉我们在一阶近似意义上，对输入图像的每个像素进行小扰动。分类会有多大的变化

# %% [markdown]
# #### 4. Intermediate features via(guided) backprop
